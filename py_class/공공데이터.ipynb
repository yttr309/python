# %%
import pandas as pd

# %%
path = r'C:\Users\user\Desktop\py_class\test.csv'
pd.read_csv(path, encoding='CP949')
# Out:
#     학번    이름  파이썬
# 0   1번   권태완   10
# 1   2번   임중섭   20
# 2   3번  멋쟁이1   30
# 3   4번  멋쟁이2   40
# 4   5번  멋쟁이3   50
# 5   6번  멋쟁이4   60
# 6   7번  멋쟁이5   70
# 7   8번  멋쟁이6   80
# 8   9번  멋쟁이7   90
# 9  10번  멋쟁이8  100

# %%
path = r'C:\Users\user\Desktop\py_class\t1.csv'
df=pd.read_csv(path, encoding='CP949')

# %%
df
# Out:
#     no          구분 작물정보
# 0    1        염증제거   마늘
# 1    2  호흡기계 감염 예방  도라지
# 2    3  호흡기계 감염 예방  도라지
# 3    4     면역력 증진    삼채
# 4    5     면역력 증진    달래
# 5    6     면역력 증진    두릅
# 6    7     면역력 증진   미나리
# 7    8        감기치료  산마늘
# 8    9        혈액순환   냉이
# 9   10     면역력 증진   토마토
# 10  11     면역력 증진    생강

# %%
df.head(3)
# Out:
#    no          구분 작물정보
# 0   1        염증제거   마늘
# 1   2  호흡기계 감염 예방  도라지
# 2   3  호흡기계 감염 예방  도라지

# %%
df.tail()
# Out:
#     no       구분 작물정보
# 6    7  면역력 증진   미나리
# 7    8     감기치료  산마늘
# 8    9     혈액순환   냉이
# 9   10  면역력 증진   토마토
# 10  11  면역력 증진    생강

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
# no      11 non-null int64
# 구분      11 non-null object
# 작물정보    11 non-null object
# dtypes: int64(1), object(2)
# memory usage: 392.0+ bytes

# %%
df.shape
# Out:
# (11, 3)

# %%
df.columns
# Out:
# Index(['no', '구분', '작물정보'], dtype='object')

# %%
df.isnull()
# Out:
#        no     구분   작물정보
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# 5   False  False  False
# 6   False  False  False
# 7   False  False  False
# 8   False  False  False
# 9   False  False  False
# 10  False  False  False

# %%
path=r'C:\Users\user\Desktop\py_class\t3.csv'
pd.read_csv(path, encoding='CP949')
# Out:
#      구분           시설명                 소 재 지  대표자           연락처  정원(병상)  비고
# 0   요양원           수지원        담양군 고서면 외보길 68  황태현  061-382-5387      29 NaN
# 1   요양원      담양하늘숲요양원     담양군 금성면 금성산성길 270  정병권  061-383-0339      22 NaN
# 2   요양원        낮은자의 집      담양군 금성면 상신기길 108  박순례  061-383-6144       9 NaN
# 3   요양원       금성노인요양원        담양군 금성면 석현길 23  최성근  061-381-7901      49 NaN
# 4   요양원       화인케어요양원    담양군 담양읍 가산길 144-26  이형수  061-383-2002      29 NaN
# 5   요양원        용화힐링타운        담양군 담양읍 남촌길 71  문지영  061-381-2254      26 NaN
# 6   요양원         에덴요양원    담양군 담양읍 삼거리길 12-10  최영희  061-383-5119      19 NaN
# 7   요양원           양지원      담양군 담양읍 월광로 3-21  하종삼  061-383-3004       9 NaN
# 8   요양원     메니노인전문요양원   담양군 담양읍 죽향문화로 178-1  김기락  061-381-0685      61 NaN
# 9   요양원   원광소규모노인종합센터     담양군 담양읍 죽향문화로 399  유화영  061-383-3844      19 NaN
# 10  요양원    담양군노인전문요양원  담양군 담양읍 죽향문화로 431-33  강성남  061-380-1400      56 NaN
# ...

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)

# %%
import this

# %%
path=r'C:\Users\user\Desktop\py_class\t5.csv'
pd.read_csv(path, encoding='CP949')
# Out:
#       학번  Java  Python    C   합계
# 0  30102    90      30   50  170
# 1  30201   100     100   90  290
# 2  30303    80     100   70  250
# 3  30501    70     100  100  270

# %%
path=r'C:\Users\user\Desktop\py_class\covid.csv'
df=pd.read_csv(path, encoding='CP949')
df
# Out:
#             시군구       의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 0       강원도 강릉시      강릉동인병원    21  608       NaN        NaN               NaN
# 1       강원도 강릉시     박정빈외과의원     1    0       NaN        NaN               NaN
# 2       강원도 강릉시     이명호내과의원     1    0       NaN        NaN               NaN
# 3       강원도 고성군       세브란의원     4    0       NaN        NaN               NaN
# 4       강원도 동해시  근로복지공단동해병원    10  499         Y        NaN               NaN
# ..          ...         ...   ...  ...       ...        ...               ...
# 314  충북 청주시 청원구      초정노인병원     3  150       NaN        NaN               NaN
# 315  충북 청주시 흥덕구      청주현대병원     4  150       NaN        NaN               NaN
# 316      충북 충주시     건국대충주병원    23  464         Y        NaN               NaN
# 317      충북 충주시      송원요양병원     2  105       NaN        NaN               NaN
# 318      충북 충주시   충주시노인전문병원     4  120       NaN        NaN               NaN
#
# [319 rows x 7 columns]

# %%
df.head(5)
# Out:
#        시군구       의료기관명  진료과수  병상수 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 0  강원도 강릉시      강릉동인병원    21  608       NaN        NaN               NaN
# 1  강원도 강릉시     박정빈외과의원     1    0       NaN        NaN               NaN
# 2  강원도 강릉시     이명호내과의원     1    0       NaN        NaN               NaN
# 3  강원도 고성군       세브란의원     4    0       NaN        NaN               NaN
# 4  강원도 동해시  근로복지공단동해병원    10  499         Y        NaN               NaN

# %%
null_count = df.isnull().sum()
df_count = null_count.reset_index()

# %%
df_count.columns=['메뉴', '결측']
df_count
# Out:
#                   메뉴   결측
# 0                시군구    0
# 1              의료기관명    0
# 2               진료과수    0
# 3                병상수    0
# 4          국민안심병원 여부  247
# 5         감염병전담기관 여부  293
# 6  감염병전담기관 외래진료 가능여부  293
